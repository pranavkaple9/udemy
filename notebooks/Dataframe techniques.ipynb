# %%
import numpy as np

arr = np.array([10, 20, 30, 40])
mask = np.array([True, False, True, False])

arr[mask] # arr[] acts as a filter and returns only those values where mask is True
# Out:
# array([10, 30])
